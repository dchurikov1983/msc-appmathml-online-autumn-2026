# %% [markdown]
# ![Прикладная математика для машинного обучения_Семинар_03.png](data:image/png;base64,...)

# %% [markdown]
# ## Семинар 3. Решение системы линейных уравнений

# %%
import numpy as np

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Реши средствами `NumPy` следующую СЛАУ:
# $$Ax=b.$$
# А. Через обратную матрицу.
#
# Б. Общим методом через NumPy.
#
# Проверь, что найденное решение верное.
#
# <font color='MediumTurquoise'>**Tip:**</font>
# numpy.linalg.solve, numpy.linalg.inv, np.array_equal -> np.allclose.

# %%
np.random.seed(42)
A = np.random.normal(0.0, 1.0, size=(4, 4))
b = np.random.normal(0.0, 1.0, size=(4, ))

# %%
# Your code here

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Дана СЛАУ:
# $$\begin{cases}
# 2x_1 + 3x_2 - x_3 = 9, \\
# x_1 + 2x_2 + x_3 = 6, \\
# 3x_1 - x_2 + 2x_3 = 1.
# \end{cases}$$
#
# Найди решение этой системы методом Крамера.
#
# <font color='MediumTurquoise'>**Tip:**</font>
# numpy.linalg.det, np.isclose, np.ndarray.flatten.

# %%
# Your code here

# %% [markdown]
# ### Задача 3

# %% [markdown]
# Компания проектирует систему распределения тепла в трёх смежных помещениях. Температуры $x_1$, $x_2$, и $x_3$ (в °C) в стационарном режиме связаны следующими соотношениями:
#
#
# \begin{cases}
# 4x_1 - x_2 = 10 + x_3, \\[6pt]
# 5x_2 - x_3 = 5 + 2x_1, \\[6pt]
# -2x_2 + 6x_3 = 15 + x_1.
# \end{cases}
#
# Найди эти температуры.

# %%
# Your code here

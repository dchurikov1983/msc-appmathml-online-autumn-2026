# %% [markdown]
# ![МАГА_Прикладная математика в ML_Шапка для Colab_Семинар.png](data:image/png;base64,...)

# %% [markdown]
# ## Семинар 1. Матрицы и векторы (начало)

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Даны две матрицы: A и B.
#
# Определи, что больше: $tr(AB)$ или $tr(BA)$?

# %%
import numpy as np

A = np.array([
    [-2, 3, -6],
    [5, -3, 2],
    [4, 1, 0],
    [7, -1, 3],
])
B = np.array([
    [2, 3, 1, 6],
    [-3, 4, -3, -2],
    [2, 1, 1, -8],
])

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Даны два вектор-столбца: a и b.
#
# Вычисли $ab^T$.

# %%
a = np.array([1, 3, 5, 7])
b = np.array([2, 4, 6, 8])

# %% [markdown]
# ### Задача 3

# %% [markdown]
# Дана матрица A.
#
# Вычисли транспонированную к ней матрицу.

# %%
A = np.array([
    [3, -1, -1],
    [1, 4, 3],
    [-2, 1, 3],
])

# %% [markdown]
# ![ОС Прикладная математика.png](data:image/png;base64,...)

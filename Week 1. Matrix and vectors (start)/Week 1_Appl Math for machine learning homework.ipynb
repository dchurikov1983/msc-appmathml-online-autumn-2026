# %% [markdown]
# ![МАГА_Прикладная математика в ML_Шапка для Colab_Домашнее задание.png](data:image/png;base64,...)

# %% [markdown]
# ## Домашнее задание 1. Матрицы и векторы (начало) (2 балла)

# %% [markdown]
# # О формате сдачи
#
# 🔷 **<font color='plum'>При решении ноутбука используй данный шаблон.</font>**
#
#     ✅ Можно добавлять новые ячейки любых типов.
#     ❌ Не нужно удалять текстовые ячейки c разметкой частей ноутбука и формулировками заданий.
#
#
# 🔷 **<font color='plum'>При оценивании задач учитывается код.</font>**
#
#     ✅ Задания, в которых необходим код, обычно помечаются фразами «Your code here» / «Твой код» и аналогичными.
#     ❌ Ответы на вопросы без сопутствующего кода оцениваются в 0 баллов.
#     ❌ Наличие работоспособного кода в ноутбуке, если на сказано иного, обязательно.
#
# 🔷 **<font color='plum'>При оценивании задач учитываются выводы.</font>**
#
#     ✅ Задания, в которых необходимы выводы, обычно помечаются фразами «Вывод» / «Ответ на вопрос» / «Твой текст» и аналогичными.
#     ✅ Обычно выводы подразумевают под собой текстовый ответ (можно писать Markdown, LaTeX).
#     ✅ Сопутствующие изображения, графики, таблички приветствуются!
#     ❌ При отсутствии выводов задание не засчитается на полный балл.

# %% [markdown]
# # О задании
#
# Тренировка использования `NumPy` в вычислениях: все задачи нужно решать при помощи средств этой библиотеки. Создавать `NumPy `-массивы можно, передавая в аргументы питоновские списки.
#
#
# Каждая из задач имеет определённую «стоимость» (указана в скобках около задачи).

# %%
import numpy as np

# %% [markdown]
# ## <font color='DarkOrange'> **Задание 1 [0,25 балла]** </font>

# %% [markdown]
# Используя библиотеку NumPy, найди матричное произведение $A \cdot B$.
#
# $A = \begin{pmatrix} 12 & 13 & 2 & -8 \\ 42 & -5 & -27 & 30 \\ 54 & 55 & -1 & 20 \\ -31 & -3 & 40 & -5 \end{pmatrix}$, $B = \begin{pmatrix} 63 & -32 & -42 & 4 \\ -6 & 55 & 11 & 1 \\ -1 & 28 & 71 & -22 \\ 35 & -34 & 36 & -15 \end{pmatrix}$.

# %%
A = # Your code here
B = # Your code here
# Your code here

# %% [markdown]
# ## <font color='DarkOrange'> **Задание 2 [0,25 балла]** </font>

# %% [markdown]
# А теперь найди матричное произведение $B \cdot A$, где $A$ и $B$ из прошлой задачи.

# %%
# Your code here

# %% [markdown]
# ## <font color='DarkOrange'> **Задание 3 [0,5 балла]** </font>

# %% [markdown]
# Верно ли, что $A \cdot B = B \cdot A$ (умножение — матричное произведение)?

# %%
# Your code here

# %% [markdown]
# ## <font color='DarkOrange'> **Задание 4 [0,5 балла]** </font>

# %% [markdown]
# Пусть $x \in \mathbb{R}^{5 \times 1},~A \in \mathbb{R}^{5 \times 3}, y \in \mathbb{R}^{3 \times 1}$.
#
# 1) <font color='DarkOrange'> **[0,25 балла]** </font> Найди $x^T \cdot A \cdot y$ , где
#
# $x = \begin{pmatrix} 2 \\ 2 \\ 3 \\ 1 \\ -1 \end{pmatrix}$, $A = \begin{pmatrix} 2 & 1 & 3 \\ 9 & -6 & -3 \\ 3 & -2 & -1 \\ 1 & 0 & -9 \\ -1 & 7 & -5 \end{pmatrix}$, $y = \begin{pmatrix} 7 \\ -8 \\ 4 \end{pmatrix}$.
#
# 2) <font color='DarkOrange'> **[0,25 балла]** </font> Какой размерности получился ответ?

# %%
x = # Your code here
y = # Your code here
A = # Your code here
# Your code here

# %% [markdown]
# ## <font color='DarkOrange'> **Задание 5 [0,5 балла]** </font>

# %% [markdown]
# Возьмём $x,y,A$ из прошлой задачи. Найди след матрицы $A^T x y^T$.

# %%
# Your code here

# %% [markdown]
# ![ОС Прикладная математика.png](data:image/png;base64,...)
